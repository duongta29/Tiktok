# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
new_width = 340
new_height = 212

# %%
img_rgb = cv2.imread('puzzle.jpg')
img_rgb = cv2.resize(img_rgb, (new_width, new_height))
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
template = cv2.imread('piece.jpg',0)
template = cv2.resize(template, (68, 68))

# %%
h, w = template.shape[::]

# %%
h1, w1 = img_gray.shape[::]

# %%
res = cv2.matchTemplate(img_gray, template, cv2.TM_CCOEFF_NORMED)

# %%
plt.imshow(res, cmap='gray')

# %%
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

# %%
top_left = max_loc
bottom_right = (top_left[0] + w, top_left[1] + h)
cv2.rectangle(img_gray, top_left, bottom_right,255,2)
# Out:
# array([[ 59,  59,  60, ..., 168, 173, 174],
#        [ 59,  60,  60, ..., 171, 175, 176],
#        [ 60,  60,  61, ..., 178, 180, 182],
#        ...,
#        [169, 172, 173, ..., 195, 198, 204],
#        [181, 171, 173, ..., 207, 203, 201],
#        [167, 176, 180, ..., 204, 204, 204]], dtype=uint8)

# %%
cv2.imshow("Match", img_gray)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
top_left[1]
# Out:
# 42
